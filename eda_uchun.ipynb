# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Jahongir\Desktop\eda\car.csv')

df.head(15)
# Out:
#                                name  year  selling_price  km_driven    fuel  \
# 0                     Maruti 800 AC  2007          60000      70000  Petrol
# 1          Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2              Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3            Datsun RediGO T Option  2017         250000      46000  Petrol
# 4             Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5              Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6         Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7          Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8          Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9          Maruti Celerio Green VXI  2017         365000      78000     CNG
# 10          Chevrolet Sail 1.2 Base  2015         260000      35000  Petrol
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   str
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   str
#  5   seller_type    4340 non-null   str
#  6   transmission   4340 non-null   str
#  7   owner          4340 non-null   str
# dtypes: int64(3), str(5)
# memory usage: 271.4 KB

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.iloc[0]
# Out:
# name             Maruti 800 AC
# year                      2007
# selling_price            60000
# km_driven                70000
# fuel                    Petrol
# seller_type         Individual
# transmission            Manual
# owner              First Owner
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.iloc[2:5]
# Out:
#                      name  year  selling_price  km_driven    fuel seller_type  \
# 2    Hyundai Verna 1.6 SX  2012         600000     100000  Diesel  Individual
# 3  Datsun RediGO T Option  2017         250000      46000  Petrol  Individual
# 4   Honda Amaze VX i-DTEC  2014         450000     141000  Diesel  Individual
#
#   transmission         owner
# 2       Manual   First Owner
# 3       Manual   First Owner
# 4       Manual  Second Owner

# %%
df.loc[0]
# Out:
# name             Maruti 800 AC
# year                      2007
# selling_price            60000
# km_driven                70000
# fuel                    Petrol
# seller_type         Individual
# transmission            Manual
# owner              First Owner
# Name: 0, dtype: object

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.index = range(1, len(df) + 1)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 1             Maruti 800 AC  2007          60000      70000  Petrol
# 2  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 3      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 4    Datsun RediGO T Option  2017         250000      46000  Petrol
# 5     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual   First Owner
# 5  Individual       Manual  Second Owner

# %%
df.iloc[0]
# Out:
# name             Maruti 800 AC
# year                      2007
# selling_price            60000
# km_driven                70000
# fuel                    Petrol
# seller_type         Individual
# transmission            Manual
# owner              First Owner
# Name: 1, dtype: object

# %%
df.loc[1]
# Out:
# name             Maruti 800 AC
# year                      2007
# selling_price            60000
# km_driven                70000
# fuel                    Petrol
# seller_type         Individual
# transmission            Manual
# owner              First Owner
# Name: 1, dtype: object

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 1             Maruti 800 AC  2007          60000      70000  Petrol
# 2  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 3      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 4    Datsun RediGO T Option  2017         250000      46000  Petrol
# 5     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual   First Owner
# 5  Individual       Manual  Second Owner

# %%
df.rename(columns={"name": "ism", "year": "chiqarilgan_yili", "selling_price": "sotilgan_narxi", "km_driven": "yurilgan_km", "fuel": "yoqilgi_turi", "seller_type": "sotuvchi_turi", "transmission": "karobka_turi", "owner": "egasi"}, inplace=True)

# %%
df
# Out:
#                                       ism  chiqarilgan_yili  sotilgan_narxi  \
# 1                           Maruti 800 AC              2007           60000
# 2                Maruti Wagon R LXI Minor              2007          135000
# 3                    Hyundai Verna 1.6 SX              2012          600000
# 4                  Datsun RediGO T Option              2017          250000
# 5                   Honda Amaze VX i-DTEC              2014          450000
# ...                                   ...               ...             ...
# 4336  Hyundai i20 Magna 1.4 CRDi (Diesel)              2014          409999
# 4337           Hyundai i20 Magna 1.4 CRDi              2014          409999
# 4338                  Maruti 800 AC BSIII              2009          110000
# 4339     Hyundai Creta 1.6 CRDi SX Option              2016          865000
# 4340                     Renault KWID RXT              2016          225000
#
# ...

# %%
df["yoqilgi_turi"]
# Out:
# 1       Petrol
# 2       Petrol
# 3       Diesel
# 4       Petrol
# 5       Diesel
#          ...
# 4336    Diesel
# 4337    Diesel
# 4338    Petrol
# 4339    Diesel
# 4340    Petrol
# Name: yoqilgi_turi, Length: 4340, dtype: str

# %%
df["yoqilgi_turi"].unique()
# Out:
# <StringArray>
# ['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric']
# Length: 5, dtype: str

# %%
df["yoqilgi_turi"] = df["yoqilgi_turi"].replace({
    "Petrol": "Benzin",
    "Diesel": "Dizel",
    "CNG": "Gaz",
    "LPG": "LPG",
    "Electric": "Elektr"
    
})

# %%
df.head()
# Out:
#                         ism  chiqarilgan_yili  sotilgan_narxi  yurilgan_km  \
# 1             Maruti 800 AC              2007           60000        70000
# 2  Maruti Wagon R LXI Minor              2007          135000        50000
# 3      Hyundai Verna 1.6 SX              2012          600000       100000
# 4    Datsun RediGO T Option              2017          250000        46000
# 5     Honda Amaze VX i-DTEC              2014          450000       141000
#
#   yoqilgi_turi sotuvchi_turi karobka_turi         egasi
# 1       Benzin    Individual       Manual   First Owner
# 2       Benzin    Individual       Manual   First Owner
# 3        Dizel    Individual       Manual   First Owner
# 4       Benzin    Individual       Manual   First Owner
# 5        Dizel    Individual       Manual  Second Owner

# %%
df["sotuvchi_turi"].unique()
# Out:
# <StringArray>
# ['Individual', 'Dealer', 'Trustmark Dealer']
# Length: 3, dtype: str

# %%
df["sotuvchi_turi"]=df["sotuvchi_turi"].replace({
    "Individual": "ozi_sotgan",
    "Dealer": "Diler_orqali",
    "Trustmark Dealer": "Ishonchli_diler_orqali"
})

# %%
df
# Out:
#                                       ism  chiqarilgan_yili  sotilgan_narxi  \
# 1                           Maruti 800 AC              2007           60000
# 2                Maruti Wagon R LXI Minor              2007          135000
# 3                    Hyundai Verna 1.6 SX              2012          600000
# 4                  Datsun RediGO T Option              2017          250000
# 5                   Honda Amaze VX i-DTEC              2014          450000
# ...                                   ...               ...             ...
# 4336  Hyundai i20 Magna 1.4 CRDi (Diesel)              2014          409999
# 4337           Hyundai i20 Magna 1.4 CRDi              2014          409999
# 4338                  Maruti 800 AC BSIII              2009          110000
# 4339     Hyundai Creta 1.6 CRDi SX Option              2016          865000
# 4340                     Renault KWID RXT              2016          225000
#
# ...

# %%
df["sotuvchi_turi"].unique()
# Out:
# <StringArray>
# ['ozi_sotgan', 'Diler_orqali', 'Ishonchli_diler_orqali']
# Length: 3, dtype: str

# %%
df["karobka_turi"].unique()
# Out:
# <StringArray>
# ['Manual', 'Automatic']
# Length: 2, dtype: str

# %%
df["karobka_turi"] = df["karobka_turi"].replace({
    "Manual": "Mexanik",
    "Automatic": "Avtomatik"
})

# %%
df
# Out:
#                                       ism  chiqarilgan_yili  sotilgan_narxi  \
# 1                           Maruti 800 AC              2007           60000
# 2                Maruti Wagon R LXI Minor              2007          135000
# 3                    Hyundai Verna 1.6 SX              2012          600000
# 4                  Datsun RediGO T Option              2017          250000
# 5                   Honda Amaze VX i-DTEC              2014          450000
# ...                                   ...               ...             ...
# 4336  Hyundai i20 Magna 1.4 CRDi (Diesel)              2014          409999
# 4337           Hyundai i20 Magna 1.4 CRDi              2014          409999
# 4338                  Maruti 800 AC BSIII              2009          110000
# 4339     Hyundai Creta 1.6 CRDi SX Option              2016          865000
# 4340                     Renault KWID RXT              2016          225000
#
# ...

# %%
df["egasi"].unique()
# Out:
# <StringArray>
# [         'First Owner',         'Second Owner', 'Fourth & Above Owner',
#           'Third Owner',       'Test Drive Car']
# Length: 5, dtype: str

# %%
df["egasi"] = df["egasi"].replace({
    "First Owner": "Birinchi_egasi",
    "Second Owner": "Ikkinchi_egasi",
    "Third Owner": "Uchinchi_egasi",
    "Fourth & Above Owner": "To'rtinchi_va_undan_yuqori_egasi",
    "Test Drive Car" : "Sinov_uchun_qoyilgan_avto"
})

# %%
df
# Out:
#                                       ism  chiqarilgan_yili  sotilgan_narxi  \
# 1                           Maruti 800 AC              2007           60000
# 2                Maruti Wagon R LXI Minor              2007          135000
# 3                    Hyundai Verna 1.6 SX              2012          600000
# 4                  Datsun RediGO T Option              2017          250000
# 5                   Honda Amaze VX i-DTEC              2014          450000
# ...                                   ...               ...             ...
# 4336  Hyundai i20 Magna 1.4 CRDi (Diesel)              2014          409999
# 4337           Hyundai i20 Magna 1.4 CRDi              2014          409999
# 4338                  Maruti 800 AC BSIII              2009          110000
# 4339     Hyundai Creta 1.6 CRDi SX Option              2016          865000
# 4340                     Renault KWID RXT              2016          225000
#
# ...

# %% [markdown]
# # Target ustunidagi qiymatlar soni:

# %%
df["sotilgan_narxi"].nunique()
# Out:
# 445

# %%
sns.barplot(x="sotuvchi_turi", y="sotilgan_narxi", data=df)
# Out:
# <Axes: xlabel='sotuvchi_turi', ylabel='sotilgan_narxi'>

# %%
sns.boxplot(x="sotuvchi_turi", y="sotilgan_narxi", data=df)
# Out:
# <Axes: xlabel='sotuvchi_turi', ylabel='sotilgan_narxi'>

# %%
missing_values = df.isnull().sum()

# %%
missing_values
# Out:
# ism                 0
# chiqarilgan_yili    0
# sotilgan_narxi      0
# yurilgan_km         0
# yoqilgi_turi        0
# sotuvchi_turi       0
# karobka_turi        0
# egasi               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4340 entries, 1 to 4340
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ism               4340 non-null   str
#  1   chiqarilgan_yili  4340 non-null   int64
#  2   sotilgan_narxi    4340 non-null   int64
#  3   yurilgan_km       4340 non-null   int64
#  4   yoqilgi_turi      4340 non-null   str
#  5   sotuvchi_turi     4340 non-null   str
#  6   karobka_turi      4340 non-null   str
#  7   egasi             4340 non-null   str
# dtypes: int64(3), str(5)
# memory usage: 271.4 KB

# %% [markdown]
# # Feature Engineering

# %%
df["car_age"] = 2026 - df["chiqarilgan_yili"]

# %%
df.head()
# Out:
#                         ism  chiqarilgan_yili  sotilgan_narxi  yurilgan_km  \
# 1             Maruti 800 AC              2007           60000        70000
# 2  Maruti Wagon R LXI Minor              2007          135000        50000
# 3      Hyundai Verna 1.6 SX              2012          600000       100000
# 4    Datsun RediGO T Option              2017          250000        46000
# 5     Honda Amaze VX i-DTEC              2014          450000       141000
#
#   yoqilgi_turi sotuvchi_turi karobka_turi           egasi  car_age
# 1       Benzin    ozi_sotgan      Mexanik  Birinchi_egasi       19
# 2       Benzin    ozi_sotgan      Mexanik  Birinchi_egasi       19
# 3        Dizel    ozi_sotgan      Mexanik  Birinchi_egasi       14
# 4       Benzin    ozi_sotgan      Mexanik  Birinchi_egasi        9
# 5        Dizel    ozi_sotgan      Mexanik  Ikkinchi_egasi       12

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

def encodlash(df):
  for col in df.columns:
    if df[col].dtype == 'string':
      if df[col].nunique() <= 5:
        dummies = pd.get_dummies(df[col], prefix=col, dtype=int)
        df = pd.concat([df.drop(columns=[col]), dummies], axis=1)
      else:
        df[col] = encoder.fit_transform(df[col])
  return df

# %%
df = encodlash(df)

# %%
df
# Out:
#        ism  chiqarilgan_yili  sotilgan_narxi  yurilgan_km  car_age  \
# 1      775              2007           60000        70000       19
# 2     1041              2007          135000        50000       19
# 3      505              2012          600000       100000       14
# 4      118              2017          250000        46000        9
# 5      279              2014          450000       141000       12
# ...    ...               ...             ...          ...      ...
# 4336   602              2014          409999        80000       12
# 4337   601              2014          409999        80000       12
# 4338   777              2009          110000        83000       17
# 4339   381              2016          865000        90000       10
# 4340  1154              2016          225000        40000       10
#
#       yoqilgi_turi_Benzin  yoqilgi_turi_Dizel  yoqilgi_turi_Elektr  \
# 1                       1                   0                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4340 entries, 1 to 4340
# Data columns (total 20 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ism                                     4340 non-null   int64
#  1   chiqarilgan_yili                        4340 non-null   int64
#  2   sotilgan_narxi                          4340 non-null   int64
#  3   yurilgan_km                             4340 non-null   int64
#  4   car_age                                 4340 non-null   int64
#  5   yoqilgi_turi_Benzin                     4340 non-null   int64
#  6   yoqilgi_turi_Dizel                      4340 non-null   int64
#  7   yoqilgi_turi_Elektr                     4340 non-null   int64
#  8   yoqilgi_turi_Gaz                        4340 non-null   int64
#  9   yoqilgi_turi_LPG                        4340 non-null   int64
#  10  sotuvchi_turi_Diler_orqali              4340 non-null   int64
# ...

# %% [markdown]
# # Feature Transformation

# %% [markdown]
# # Skewnessni tekshirish

# %%
num_cols = ["sotilgan_narxi", "yurilgan_km", "car_age"]

skewness = df[num_cols].skew()
print(skewness)
# Out:
# sotilgan_narxi    4.892021
# yurilgan_km       2.669057
# car_age           0.833240
# dtype: float64

# %%
df["sotilgan_narxi"] = np.log1p(df["sotilgan_narxi"])
df["yurilgan_km"] = np.log1p(df["yurilgan_km"])
df["car_age"] = np.log1p(df["car_age"])

# %%
num_cols = ["sotilgan_narxi", "yurilgan_km", "car_age"]

skewness = df[num_cols].skew()
print(skewness)
# Out:
# sotilgan_narxi    0.060173
# yurilgan_km      -1.821874
# car_age           0.133026
# dtype: float64

# %%
df["yurilgan_km"] = np.expm1(df["yurilgan_km"])

# %%
num_cols = ["sotilgan_narxi", "yurilgan_km", "car_age"]

skewness = df[num_cols].skew()
print(skewness)
# Out:
# sotilgan_narxi    0.060173
# yurilgan_km       2.669057
# car_age           0.133026
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4340 entries, 1 to 4340
# Data columns (total 20 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ism                                     4340 non-null   int64
#  1   chiqarilgan_yili                        4340 non-null   int64
#  2   sotilgan_narxi                          4340 non-null   float64
#  3   yurilgan_km                             4340 non-null   float64
#  4   car_age                                 4340 non-null   float64
#  5   yoqilgi_turi_Benzin                     4340 non-null   int64
#  6   yoqilgi_turi_Dizel                      4340 non-null   int64
#  7   yoqilgi_turi_Elektr                     4340 non-null   int64
#  8   yoqilgi_turi_Gaz                        4340 non-null   int64
#  9   yoqilgi_turi_LPG                        4340 non-null   int64
# ...

# %%
from sklearn.preprocessing import StandardScaler

standart_scaler = StandardScaler()

def scalinglash(df):
  num_col = df.select_dtypes(include=["int64", "float64"]).columns.drop("sotilgan_narxi")
  df[num_col] = standart_scaler.fit_transform(df[num_col])
  return df

# %%
df = scalinglash(df)

# %%
df
# Out:
#            ism  chiqarilgan_yili  sotilgan_narxi  yurilgan_km   car_age  \
# 1     0.058522         -1.445074       11.002117     0.081139  1.381524
# 2     0.723520         -1.445074       11.813037    -0.347689  1.381524
# 3    -0.616477         -0.258795       13.304687     0.724381  0.404935
# 4    -1.583975          0.927485       12.429220    -0.433455 -0.971491
# 5    -1.181476          0.215717       13.017005     1.603479 -0.080847
# ...        ...               ...             ...          ...       ...
# 4336 -0.373977          0.215717       12.923912     0.295553 -0.080847
# 4337 -0.376477          0.215717       12.923912     0.295553 -0.080847
# 4338  0.063522         -0.970563       11.608245     0.359877  1.023859
# 4339 -0.926476          0.690229       13.670486     0.509967 -0.647943
# 4340  1.006020          0.690229       12.323860    -0.562103 -0.647943
#
#       yoqilgi_turi_Benzin  yoqilgi_turi_Dizel  yoqilgi_turi_Elektr  \
# ...

# %% [markdown]
# # Feature Selection

# %%
df = df.drop("chiqarilgan_yili", axis=1)

# %%
df
# Out:
#            ism  sotilgan_narxi  yurilgan_km   car_age  yoqilgi_turi_Benzin  \
# 1     0.058522       11.002117     0.081139  1.381524             1.021899
# 2     0.723520       11.813037    -0.347689  1.381524             1.021899
# 3    -0.616477       13.304687     0.724381  0.404935            -0.978571
# 4    -1.583975       12.429220    -0.433455 -0.971491             1.021899
# 5    -1.181476       13.017005     1.603479 -0.080847            -0.978571
# ...        ...             ...          ...       ...                  ...
# 4336 -0.373977       12.923912     0.295553 -0.080847            -0.978571
# 4337 -0.376477       12.923912     0.295553 -0.080847            -0.978571
# 4338  0.063522       11.608245     0.359877  1.023859             1.021899
# 4339 -0.926476       13.670486     0.509967 -0.647943            -0.978571
# 4340  1.006020       12.323860    -0.562103 -0.647943             1.021899
#
#       yoqilgi_turi_Dizel  yoqilgi_turi_Elektr  yoqilgi_turi_Gaz  \
# ...

# %% [markdown]
# # Filtering >>> Highly Correlated Features

# %%
import numpy as np 
corr_matrix = df.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [col for col in upper.columns if any(upper[col] > 0.9)]
df_filtered = df.drop(columns=to_drop)
print("\nOriginal shaoe: ", df.shape)
print("Shape after dropping high;y correlated features: ", df_filtered.shape)
# Out:
# Original shaoe:  (4340, 19)
# Shape after dropping high;y correlated features:  (4340, 16)

# %%
df_filtered.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4340 entries, 1 to 4340
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ism                                     4340 non-null   float64
#  1   sotilgan_narxi                          4340 non-null   float64
#  2   yurilgan_km                             4340 non-null   float64
#  3   car_age                                 4340 non-null   float64
#  4   yoqilgi_turi_Benzin                     4340 non-null   float64
#  5   yoqilgi_turi_Elektr                     4340 non-null   float64
#  6   yoqilgi_turi_Gaz                        4340 non-null   float64
#  7   yoqilgi_turi_LPG                        4340 non-null   float64
#  8   sotuvchi_turi_Diler_orqali              4340 non-null   float64
#  9   sotuvchi_turi_Ishonchli_diler_orqali    4340 non-null   float64
# ...

# %%
df = df_filtered

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4340 entries, 1 to 4340
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ism                                     4340 non-null   float64
#  1   sotilgan_narxi                          4340 non-null   float64
#  2   yurilgan_km                             4340 non-null   float64
#  3   car_age                                 4340 non-null   float64
#  4   yoqilgi_turi_Benzin                     4340 non-null   float64
#  5   yoqilgi_turi_Elektr                     4340 non-null   float64
#  6   yoqilgi_turi_Gaz                        4340 non-null   float64
#  7   yoqilgi_turi_LPG                        4340 non-null   float64
#  8   sotuvchi_turi_Diler_orqali              4340 non-null   float64
#  9   sotuvchi_turi_Ishonchli_diler_orqali    4340 non-null   float64
# ...

# %% [markdown]
# # MODEL SELECTION

# %%
x = df.drop("sotilgan_narxi", axis=1)
y = df["sotilgan_narxi"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test, = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %% [markdown]
# # Linear regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score  

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_val)
mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 0.22114054363187266
# R^2 Score: 0.6438916142023543

# %% [markdown]
# # SVM Model

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

model = SVR()
model.fit(x_train, y_train)
y_pred = model.predict(x_val)
mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)

print(f"SVM modelda Mean Squared Error: {mse}")
print(f"SVM modelda R^2 Score: {r2}")
# Out:
# SVM modelda Mean Squared Error: 0.19817314918578566
# SVM modelda R^2 Score: 0.680876608576742

# %% [markdown]
# # GradientBoosting model

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor()
model.fit(x_train, y_train)

y_pred = model.predict(x_val)
mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)

print(f"Gradient Boosting modelda Mean Squared Error: {mse}")
print(f"Gradient Boosting modelda R^2 Score: {r2}")
# Out:
# Gradient Boosting modelda Mean Squared Error: 0.12376807364473812
# Gradient Boosting modelda R^2 Score: 0.8006930425554069

# %% [markdown]
# # Model Evaluation >>>  K Fold

# %% [markdown]
# # CROSS VALIDATION  R2 Uchun

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.model_selection import KFold, cross_val_score
kfold = KFold(
    n_splits=5,   
    shuffle=True,    
    random_state=42
)

# %%
from sklearn.pipeline import Pipeline
pipeline =  Pipeline(steps=[
    ("scaler", StandardScaler()),
    ("model", LinearRegression())
])

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

model = LinearRegression()

scores = cross_val_score(
    estimator=pipeline,
    X=x_train,
    y=y_train,
    cv=kfold,
    scoring="r2"
)

print("Har bir fold accuracy natijasi: ", scores)
print("O`rtacha accuracy: ", scores.mean())
print("Standart og`ish: ", scores.std())
# Out:
# Har bir fold accuracy natijasi:  [0.71765461 0.69077514 0.71489164 0.70972966 0.74737855]
# O`rtacha accuracy:  0.716085920159582
# Standart og`ish:  0.018243647454176712

# %%
scores = cross_val_score(
    estimator=pipeline,
    X=x_train,
    y=y_train,
    cv=kfold,
    scoring="neg_mean_squared_error"
)

print("Har bir fold r2 natijasi: ", abs(scores))
print("O`rtacha r2: ", abs(scores.mean()))
print("Standart og`ish: ", scores.std())
# Out:
# Har bir fold r2 natijasi:  [0.20625969 0.20899626 0.2075926  0.20727274 0.17344311]
# O`rtacha r2:  0.20071287916135372
# Standart og`ish:  0.013662974561235582

# %% [markdown]
# # SVM BILAN CROSS VALIDATION

# %%
from sklearn.model_selection import KFold, cross_val_score
kfold = KFold(
    n_splits=5,   
    shuffle=True,    
    random_state=42
)

# %%
from sklearn.pipeline import Pipeline
pipeline =  Pipeline(steps=[
    ("scaler", StandardScaler()),
    ("model", SVR())
])

# %%
model = SVR()

scores = cross_val_score(
    estimator=pipeline,
    X=x_train,
    y=y_train,
    cv=kfold,
    scoring="r2"
)

print("Har bir fold r2 natijasi: ", scores)
print("O`rtacha r2: ", scores.mean())
print("Standart og`ish: ", scores.std())
# Out:
# Har bir fold r2 natijasi:  [0.71765461 0.69077514 0.71489164 0.70972966 0.74737855]
# O`rtacha r2:  0.716085920159582
# Standart og`ish:  0.018243647454176712

# %%
scores = cross_val_score(
    estimator=pipeline,
    X=x_train,
    y=y_train,
    cv=kfold,
    scoring="neg_mean_squared_error"
)

print("Har bir fold accuracy natijasi: ", abs(scores))
print("O`rtacha accuracy: ", abs(scores.mean()))
print("Standart og`ish: ", scores.std())
# Out:
# Har bir fold accuracy natijasi:  [0.20625969 0.20899626 0.2075926  0.20727274 0.17344311]
# O`rtacha accuracy:  0.20071287916135372
# Standart og`ish:  0.013662974561235582

# %% [markdown]
# # Overfitting va Underfitting tekshirish

# %%
models = {
    "Linear": LinearRegression(),
    "SVR": SVR()
}

for name, model in models.items():
    model.fit(x_train, y_train)
    
    train_score = model.score(x_train, y_train)
    val_score = model.score(x_val, y_val)
    
    print(f"{name} → Train: {train_score:.3f}, Val: {val_score:.3f}")
# Out:
# Linear → Train: 0.690, Val: 0.644
# SVR → Train: 0.746, Val: 0.681

# %% [markdown]
# # Ushbu natijalardan kelib chiqib bizda SVR Model yaxshi natija berganini ko'rish mumkin va Keyingi bosqichda SVR Model bilan ishlaymiz

# %% [markdown]
# # Hyperparametr Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", SVR())
])

param_grid = {
    "model__kernel": ["rbf"],
    "model__C": [1, 10, 100],
    "model__epsilon": [0.01, 0.1, 0.5],
    "model__gamma": ["scale", "auto"]
}

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=5,
    scoring="r2",
    n_jobs=1
)

grid.fit(x_train, y_train)

print("Best params:", grid.best_params_)
print("Best score:", grid.best_score_)
# Out:
# Best params: {'model__C': 10, 'model__epsilon': 0.1, 'model__gamma': 'auto', 'model__kernel': 'rbf'}
# Best score: 0.7189734490358626

# %% [markdown]
# # Modelni Saqlash

# %%
import joblib

joblib.dump(grid, "car_price_svr_model.joblib")
joblib.dump(standart_scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %% [markdown]
# # Modelni papkaga saqlab olish

# %%
import joblib 
import os 

save_dir = r"C:\Users\Jahongir\Desktop\eda\Models"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

model_path = os.path.join(save_dir, "car_price_svr_model.joblib")
scaler_path = os.path.join(save_dir, "scaler.joblib")

joblib.dump(grid, model_path)
joblib.dump(standart_scaler, scaler_path)

print(f"Model Saqlandi : {model_path}")
print(f"Scaler Saqlandi: {scaler_path}")
# Out:
# Model Saqlandi : C:\Users\Jahongir\Desktop\eda\Models\car_price_svr_model.joblib
# Scaler Saqlandi: C:\Users\Jahongir\Desktop\eda\Models\scaler.joblib
